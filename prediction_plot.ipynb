# %%
import predictions
import model_builder 
import random 
from glob import glob
import torch

# %%
len(glob('data/dog_cat/test/**/*.jpg', recursive=True))
# Out:
# 2023

# %%
PATH = './models/best_alexnet_model.pth'
class_names = ['pizza', 'steak', 'sushi']
model = model_builder.AlexNet(3)
model.load_state_dict(torch.load(PATH)['model_state_dict'])
model.eval()
# Out:
# AlexNet(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU()
#     (2): LocalResponseNorm(5, alpha=0.0001, beta=0.75, k=2)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): LocalResponseNorm(5, alpha=0.0001, beta=0.75, k=2)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_3): Sequential(
#     (0): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv_block_4): Sequential(
#     (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (conv_block_5): Sequential(
#     (0): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
# ...

# %%
image_path = random.choice(glob('data/pizza_steak_sushi/test/**/*.jpg', recursive=True))
predictions.pred_and_plot_image(model, class_names, image_path)
